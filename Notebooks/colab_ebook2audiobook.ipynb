# %% [markdown]
# <a href="https://colab.research.google.com/github/nyamabites/colab/blob/main/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook free google colab!
# ## 🌟 Features
#
# - 📖 Converts eBooks to text format with Calibre.
# - 📚 Splits eBook into chapters for organized audio.
# - 🎙️ High-quality text-to-speech with [Coqui XTTS](https://huggingface.co/coqui/XTTS-v2), [Fairseq](https://github.com/facebookresearch/fairseq), [Bark](https://github.com/suno-ai/bark), [Vits](https://github.com/jaywalnut310/vits), and [Yourtts](https://github.com/Edresson/YourTTS).
# - 🗣️ Optional voice cloning with your own voice file or choose from our pre-made fine-tuned models!
# - 🌍 Supports multiple languages! Arabic (ar), Chinese (zh-cn), Czech (cs), Dutch (nl), English (en), French (fr), German (de), Hindi (hi), Hungarian (hu), Italian (it), Japanese (ja), Korean (ko), Polish (pl), Portuguese (pt), Russian (ru), Spanish (es), Turkish (tr), Vietnamese (vi), [+ 1107 languages via Fairseq](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html)
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🚀 Run ebook2audiobook!

import os
import re
import subprocess
import time  # Import the time module
from IPython.display import HTML, display
import pkg_resources  # For checking installed packages

# Emojis for logs
CHECK_MARK = "✅"
CROSS_MARK = "❌"

def display_loading_bar(total_steps):
    """Displays a more visual text-based loading indicator in Colab."""
    print("\n---  LOADING...  Total steps:", total_steps, " ---") # Separator and loading start

def update_progress(step, total_steps):
  """Updates the text-based loading indicator with a bar-like style."""
  bar_length = 20  # Length of the "bar"
  progress_percent = int((step / total_steps) * 100)
  progress_filled = int(bar_length * step / total_steps)
  bar = '=' * progress_filled + '>' + ' ' * (bar_length - progress_filled -1 if (bar_length - progress_filled -1) >= 0 else 0) # Handle potential index error
  progress_text = f"[{bar}] {progress_percent}% ({step}/{total_steps})"
  print(f"---  PROGRESS:  {progress_text} ---") # Separator for progress update

def run_command_with_log(command, description, step_progress, total_step_commands):
    """Runs a command and logs its progress and outcome with emojis and duration."""
    print(f"\n{step_progress}/{total_step_commands}: {description}...")
    start_time = time.time()  # Record start time
    try:
        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()
        end_time = time.time()  # Record end time
        duration = end_time - start_time # Calculate duration
        duration_formatted = "{:.2f}".format(duration) # Format duration to 2 decimal places

        if process.returncode != 0:
            print(f"{CROSS_MARK} Command failed: {description} (Took {duration_formatted} seconds)")
            print(f"   Command: {command}")
            print(f"   Error Output:\n{stderr.decode()}")
            return False
        else:
            update_progress(step_progress, total_step_commands) # Use updated progress function
            print(f"{CHECK_MARK} Command {step_progress}/{total_step_commands} completed: {description} (Took {duration_formatted} seconds)")
            return True

    except Exception as e:
        end_time = time.time()  # Record end time even if exception occurs
        duration = end_time - start_time # Calculate duration
        duration_formatted = "{:.2f}".format(duration) # Format duration
        print(f"{CROSS_MARK} A general error occurred during command: {description} (Took {duration_formatted} seconds)")
        print(f"   Error: {e}")
        return False

# --- Step 1: OS-Level Installations ---
os_install_commands = [
    ("sudo apt-get update", "Updating software package lists (Takes around 14.14 seconds)"),
    ("apt-get install -y libxcb-cursor0", "Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds)"),
    ("sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin", "Download & install Calibre ebook manager(Takes around 29.40 seconds)"),
    ("apt-get install -y libegl1", "Install graphics library (libegl1) (Takes around 4.12 seconds)"),
    ("apt-get install -y libopengl0", "Install graphics library (libopengl0) (Takes around 3.07 seconds)"),
    ("apt-get install -y ffmpeg", "Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds)"),
    ("apt-get install -y espeak-ng", "Install espeak-ng (espeak-ng tts engine) (Takes around 3.52 seconds)"),
    ("apt-get install -y mecab", "Install mecab (Japanese text analysis) (Takes around 14.51 seconds)"),
    ("apt-get install -y libmecab-dev", "Install mecab development files (Takes around 5.72 seconds)"),
    ("apt-get install -y mecab-ipadic-utf8", "Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds)"),
    ("apt-get install -y nodejs", "Install nodejs (Javascript runtime) (Takes around 7.03 seconds)"),
    ("pip install mecab-python3 unidic-lite", "Install mecab-python3 (Takes around 19.80 seconds)"),
    ("pip install unidic-lite", "Install lightweight unidic dictionary (Takes around 2.15 seconds)"),
    ("pip install unidic", "Install full Unidic dictionary (Takes around 4.00 seconds)"),
    ("python -m unidic download", "Download Unidic dictionary data (Takes around 29.05 seconds)"),
]
os_install_completed = False

# --- Step 2: Git Clone & Requirements ---
git_requirements_commands = [
    ("git clone https://github.com/DrewThomasson/ebook2audiobook.git", "Git clone Ebook2audiobook"),
    ("pip install -r /content/ebook2audiobook/requirements.txt", "Install Python requirements (Takes around 202.4 seconds)"),
]
git_requirements_completed = False

# --- Step 3: Run App ---
run_app_completed = False


# --- Step 1 Execution ---
if os_install_completed:
    print("\nStep 1: OS-Level Installations - Already completed, skipping.")
else:
    print("\n--- Step 1: OS-Level Installations ---")
    print("This step installs essential software on the Colab system. (Takes around 3-4 minutes)")
    total_steps_step1 = len(os_install_commands)
    display_loading_bar(total_steps_step1) # Start enhanced loading indicator

    step1_success = True
    for i, (command, description) in enumerate(os_install_commands):
        if not run_command_with_log(command, description, i + 1, total_steps_step1):
            step1_success = False
            break

    if step1_success:
        os_install_completed = True
        print(f"\n{CHECK_MARK} Step 1: OS-Level Installations - Completed Successfully!")
    else:
        print(f"\n{CROSS_MARK} Step 1: OS-Level Installations - Failed. See error messages above.")


# --- Step 2 Execution ---
if git_requirements_completed:
    print("\nStep 2: Git Clone & Requirements - Already completed, skipping.")
else:
    print("\n--- Step 2: Git Clone & Requirements ---")
    print("This step downloads program files and installs Python components. (Takes around 3-4 minutes)")
    total_steps_step2 = len(git_requirements_commands)
    display_loading_bar(total_steps_step2) # Start enhanced loading indicator

    step2_success = True
    for i, (command, description) in enumerate(git_requirements_commands):
        if not run_command_with_log(command, description, i + 1, total_steps_step2):
            step2_success = False
            break

    if step2_success:
        git_requirements_completed = True
        print(f"\n{CHECK_MARK} Step 2: Git Clone & Requirements - Completed Successfully!")
    else:
        print(f"\n{CROSS_MARK} Step 2: Git Clone & Requirements - Failed. See error messages above.")


def modify_python_version(filepath, new_version=(3, 11)):
    """
    Modifies the min_python_version in a Python file.
    (Function definition - same as before)
    """
    try:
        with open(filepath, 'r') as f:
            file_content = f.read()
        pattern = r"min_python_version = \(\s*(\d+)\s*,\s*(\d+)\s*\)"
        def replacement(match):
            return f"min_python_version = ({new_version[0]}, {new_version[1]})"
        new_content = re.sub(pattern, replacement, file_content)
        if new_content != file_content:
            with open(filepath, 'w') as f:
                f.write(new_content)
            print(f"Successfully changed min_python_version in {filepath} to {new_version}")
        else:
            print(f"min_python_version in {filepath} was already {new_version} or not found.")
    except FileNotFoundError:
        print(f"Error: File not found: {filepath}")
    except Exception as e:
        print(f"An error occurred: {e}")

def fix_functions_py(filepath):
    """
    Scans functions.py and fixes the incorrect f-string issue if found.
    """
    # Define the incorrect pattern (allowing indentation and triple quotes)
    incorrect_pattern = r"msg\s*=\s*f'Voice file \{re\.sub\(r'_\(24000\|16000\)\\.wav\$', '', selected_name\)\} deleted!'"

    # Correct replacement (keeping indentation)
    correct_replacement = """                        cleaned_name = re.sub(r'_(24000|16000)\\.wav$', '', selected_name)
                        msg = f"Voice file {cleaned_name} deleted!" """

    try:
        # Read the file
        with open(filepath, "r") as file:
            lines = file.readlines()

        # Check and replace the incorrect line
        modified_lines = []
        fixed = False

        for line in lines:
            if re.search(incorrect_pattern, line.strip()):  # Use regex search instead of exact match
                print("🔍 Found incorrect line in functions.py. Fixing it now...")
                modified_lines.append(correct_replacement + "\n")  # Add the corrected version
                fixed = True
            else:
                modified_lines.append(line)  # Keep other lines unchanged

        # Only overwrite the file if a fix was applied
        if fixed:
            with open(filepath, "w") as file:
                file.writelines(modified_lines)
            print("✅ Fix applied successfully!")
        else:
            print("✅ No fix needed. The exact error line was not found.")

    except FileNotFoundError:
        print(f"❌ Error: The file {filepath} was not found.")
    except Exception as e:
        print(f"❌ An error occurred: {e}")

# Modify conf.py AFTER git clone (Step 2 ensures clone is done)
filepath = "/content/ebook2audiobook/lib/conf.py"
modify_python_version(filepath)

# Call the function to fix functions.py
filepath = "/content/ebook2audiobook/lib/functions.py"
fix_functions_py(filepath)




# --- Step 3 Execution ---
if run_app_completed:
    print("\nStep 3: Run App - Already run (or skipped).")
else:
    print("\n--- Step 3: Run App ---")
    print("This step starts the ebook2audiobook web interface.")
    print("Starting ebook2audiobook...")
    try:
        # !cd ebook2audiobook && python app.py --script_mode full_docker --share
        run_app_completed = True
    except Exception as e:
        print(f"{CROSS_MARK} Error starting app.py: {e}")
    else:
        print(f"\n{CHECK_MARK} Step 3: Run App - Started! Check the output above for the Gradio link.")


print("\n--- All Steps Initiated (or Skipped if Already Run) ---")
print("Check the output above for details on each step.")
# Out:
# /tmp/ipython-input-3707221739.py:8: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources  # For checking installed packages
# --- Step 1: OS-Level Installations ---
# This step installs essential software on the Colab system. (Takes around 3-4 minutes)
#
# ---  LOADING...  Total steps: 15  ---
#
# 1/15: Updating software package lists (Takes around 14.14 seconds)...
# ---  PROGRESS:  [=>                  ] 6% (1/15) ---
# ✅ Command 1/15 completed: Updating software package lists (Takes around 14.14 seconds) (Took 6.91 seconds)
#
# 2/15: Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds)...
# ---  PROGRESS:  [==>                 ] 13% (2/15) ---
# ✅ Command 2/15 completed: Install cursor display library (libxcb-cursor0 - for Calibre) (Takes around 12.99 seconds) (Took 8.99 seconds)
#
# 3/15: Download & install Calibre ebook manager(Takes around 29.40 seconds)...
# ---  PROGRESS:  [====>               ] 20% (3/15) ---
# ✅ Command 3/15 completed: Download & install Calibre ebook manager(Takes around 29.40 seconds) (Took 20.47 seconds)
#
# 4/15: Install graphics library (libegl1) (Takes around 4.12 seconds)...
# ---  PROGRESS:  [=====>              ] 26% (4/15) ---
# ✅ Command 4/15 completed: Install graphics library (libegl1) (Takes around 4.12 seconds) (Took 2.54 seconds)
#
# 5/15: Install graphics library (libopengl0) (Takes around 3.07 seconds)...
# ---  PROGRESS:  [======>             ] 33% (5/15) ---
# ✅ Command 5/15 completed: Install graphics library (libopengl0) (Takes around 3.07 seconds) (Took 2.38 seconds)
#
# 6/15: Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds)...
# ---  PROGRESS:  [========>           ] 40% (6/15) ---
# ✅ Command 6/15 completed: Install ffmpeg (audio/video conversion) (Takes around 3.52 seconds) (Took 2.22 seconds)
#
# 7/15: Install espeak-ng (espeak-ng tts engine) (Takes around 3.52 seconds)...
# ---  PROGRESS:  [=========>          ] 46% (7/15) ---
# ✅ Command 7/15 completed: Install espeak-ng (espeak-ng tts engine) (Takes around 3.52 seconds) (Took 6.33 seconds)
#
# 8/15: Install mecab (Japanese text analysis) (Takes around 14.51 seconds)...
# ---  PROGRESS:  [==========>         ] 53% (8/15) ---
# ✅ Command 8/15 completed: Install mecab (Japanese text analysis) (Takes around 14.51 seconds) (Took 14.04 seconds)
#
# 9/15: Install mecab development files (Takes around 5.72 seconds)...
# ---  PROGRESS:  [============>       ] 60% (9/15) ---
# ✅ Command 9/15 completed: Install mecab development files (Takes around 5.72 seconds) (Took 5.23 seconds)
#
# 10/15: Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds)...
# ---  PROGRESS:  [=============>      ] 66% (10/15) ---
# ✅ Command 10/15 completed: Install mecab Japanese dictionary (UTF-8) (Takes around 9.58 seconds) (Took 10.30 seconds)
#
# 11/15: Install nodejs (Javascript runtime) (Takes around 7.03 seconds)...
# ---  PROGRESS:  [==============>     ] 73% (11/15) ---
# ✅ Command 11/15 completed: Install nodejs (Javascript runtime) (Takes around 7.03 seconds) (Took 6.93 seconds)
#
# 12/15: Install mecab-python3 (Takes around 19.80 seconds)...
# ---  PROGRESS:  [================>   ] 80% (12/15) ---
# ✅ Command 12/15 completed: Install mecab-python3 (Takes around 19.80 seconds) (Took 19.48 seconds)
#
# 13/15: Install lightweight unidic dictionary (Takes around 2.15 seconds)...
# ---  PROGRESS:  [=================>  ] 86% (13/15) ---
# ✅ Command 13/15 completed: Install lightweight unidic dictionary (Takes around 2.15 seconds) (Took 2.22 seconds)
#
# 14/15: Install full Unidic dictionary (Takes around 4.00 seconds)...
# ---  PROGRESS:  [==================> ] 93% (14/15) ---
# ✅ Command 14/15 completed: Install full Unidic dictionary (Takes around 4.00 seconds) (Took 4.91 seconds)
#
# 15/15: Download Unidic dictionary data (Takes around 29.05 seconds)...
# ---  PROGRESS:  [====================>] 100% (15/15) ---
# ✅ Command 15/15 completed: Download Unidic dictionary data (Takes around 29.05 seconds) (Took 25.92 seconds)
#
# ✅ Step 1: OS-Level Installations - Completed Successfully!
#
# --- Step 2: Git Clone & Requirements ---
# This step downloads program files and installs Python components. (Takes around 3-4 minutes)
#
# ---  LOADING...  Total steps: 2  ---
#
# 1/2: Git clone Ebook2audiobook...
# ---  PROGRESS:  [==========>         ] 50% (1/2) ---
# ✅ Command 1/2 completed: Git clone Ebook2audiobook (Took 26.83 seconds)
#
# 2/2: Install Python requirements (Takes around 202.4 seconds)...
# ---  PROGRESS:  [====================>] 100% (2/2) ---
# ✅ Command 2/2 completed: Install Python requirements (Takes around 202.4 seconds) (Took 115.76 seconds)
#
# ✅ Step 2: Git Clone & Requirements - Completed Successfully!
# Successfully changed min_python_version in /content/ebook2audiobook/lib/conf.py to (3, 11)
# ✅ No fix needed. The exact error line was not found.
#
# --- Step 3: Run App ---
# This step starts the ebook2audiobook web interface.
# Starting ebook2audiobook...
# v25.8.18 full_docker mode
# /usr/local/lib/python3.12/dist-packages/pyannote/audio/core/io.py:212: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   torchaudio.list_audio_backends()
# /usr/local/lib/python3.12/dist-packages/speechbrain/utils/torch_audio_backend.py:57: UserWarning: torchaudio._backend.list_audio_backends has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   available_backends = torchaudio.list_audio_backends()
# IPs available for connection:
# ['127.0.0.1', '172.28.0.12']
# Note: 0.0.0.0 is not the IP to connect. Instead use an IP above to connect.
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://cef87eef12576329d4.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Processing eBook file: Mind Management, Not Time Management.epub
# Using CUDA -
# Running command: /usr/bin/ebook-convert /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/Mind Management, Not Time Management.epub /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/__Mind Management, Not Time Management.epub
# Conversion options changed from defaults:
#   smarten_punctuation: True
#   disable_font_rescaling: True
#   flow_size: 0
#   output_profile: 'generic_eink'
#   epub_version: '3'
#   page_breaks_before: "//*[name()='h1' or name()='h2' or name()='h3' or name()='h4' or name()='h5']"
#   verbose: 1
#   input_encoding: 'utf-8'
# 1% Converting input to HTML...
# InputFormatPlugin: EPUB Input running
# on /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/Mind Management, Not Time Management.epub
# Found HTML cover OEBPS/Text/cover.xhtml
# Parsing all content...
# Parsing OEBPS/Text/cover.xhtml ...
# Parsing OEBPS/Text/mmt-manuscript.html ...
# Parsing OEBPS/Styles/styles.css ...
# Parsing OEBPS/Text/MMT.html ...
# Parsing OEBPS/Styles/sgc-toc.css ...
# Parsing OEBPS/Text/TOC.xhtml ...
# Parsing OEBPS/Text/Front-Matter.html ...
# Reading TOC from NCX...
# 34% Running transforms on e-book...
# Merging user specified metadata...
# Detecting structure...
# 	Detected chapter: Epilogue
# 	Detected chapter: Chapter 1
# 	Detected chapter: Chapter 2
# 	Detected chapter: Chapter 3
# 	Detected chapter: Chapter 4
# 	Detected chapter: Chapter 5
# 	Detected chapter: Chapter 6
# 	Detected chapter: Chapter 7
# Flattening CSS and remapping font sizes...
# Source base font size is 12.00000pt
# Removing fake margins...
# Found 978 items of level: p_1
# Found 22 items of level: div_1
# Found 65 items of level: div_2
# Found 17 items of level: p_2
# Ignoring level p_2
# p_1  left margin stats: Counter({'0': 978})
# p_1  right margin stats: Counter({'0': 978})
# div_1  left margin stats: Counter({'0': 7})
# div_1  right margin stats: Counter({'0': 7})
# div_2  left margin stats: Counter()
# div_2  right margin stats: Counter()
# Cleaning up manifest...
# Trimming unused files from manifest...
# Creating EPUB Output...
# 67% Running EPUB Output plugin
# Splitting markup on page breaks and flow limits, if any...
# 		Splitting on page-break at id=calibre_pb_0
# 		Splitting on page-break at id=sigil_toc_id_24
# 		Splitting on page-break at id=sigil_toc_id_25
# 		Splitting on page-break at id=sigil_toc_id_26
# 		Splitting on page-break at id=sigil_toc_id_27
# 		Splitting on page-break at id=sigil_toc_id_28
# 		Splitting on page-break at id=sigil_toc_id_29
# 		Splitting on page-break at id=sigil_toc_id_30
# 		Splitting on page-break at id=sigil_toc_id_31
# 		Splitting on page-break at id=sigil_toc_id_32
# 		Splitting on page-break at id=sigil_toc_id_33
# 		Splitting on page-break at id=sigil_toc_id_34
# 		Splitting on page-break at id=sigil_toc_id_35
# 		Splitting on page-break at id=sigil_toc_id_36
# 		Splitting on page-break at id=sigil_toc_id_37
# 		Splitting on page-break at id=sigil_toc_id_38
# 		Splitting on page-break at id=sigil_toc_id_39
# 		Splitting on page-break at id=sigil_toc_id_40
# 		Splitting on page-break at id=sigil_toc_id_41
# 		Splitting on page-break at id=sigil_toc_id_42
# 		Splitting on page-break at id=sigil_toc_id_43
# 		Splitting on page-break at id=sigil_toc_id_44
# 		Splitting on page-break at id=sigil_toc_id_45
# 		Splitting on page-break at id=sigil_toc_id_46
# 		Splitting on page-break at id=sigil_toc_id_47
# 		Splitting on page-break at id=sigil_toc_id_48
# 		Splitting on page-break at id=sigil_toc_id_49
# 		Splitting on page-break at id=sigil_toc_id_50
# 		Splitting on page-break at id=sigil_toc_id_51
# 		Splitting on page-break at id=sigil_toc_id_52
# 		Splitting on page-break at id=sigil_toc_id_53
# 		Splitting on page-break at id=sigil_toc_id_54
# 		Splitting on page-break at id=sigil_toc_id_55
# 		Splitting on page-break at id=sigil_toc_id_56
# 		Splitting on page-break at id=sigil_toc_id_57
# 		Splitting on page-break at id=sigil_toc_id_58
# 		Splitting on page-break at id=sigil_toc_id_59
# 		Splitting on page-break at id=sigil_toc_id_60
# 		Splitting on page-break at id=sigil_toc_id_61
# 		Splitting on page-break at id=sigil_toc_id_62
# 		Splitting on page-break at id=sigil_toc_id_63
# 		Splitting on page-break at id=sigil_toc_id_64
# 		Splitting on page-break at id=sigil_toc_id_65
# 		Splitting on page-break at id=sigil_toc_id_66
# 		Splitting on page-break at id=sigil_toc_id_67
# 		Splitting on page-break at id=sigil_toc_id_68
# 		Splitting on page-break at id=sigil_toc_id_69
# 		Splitting on page-break at id=sigil_toc_id_70
# 		Splitting on page-break at id=sigil_toc_id_71
# 		Splitting on page-break at id=sigil_toc_id_72
# 		Splitting on page-break at id=sigil_toc_id_73
# 		Splitting on page-break at id=sigil_toc_id_74
# 		Splitting on page-break at id=sigil_toc_id_75
# 		Splitting on page-break at id=sigil_toc_id_76
# 		Splitting on page-break at id=sigil_toc_id_77
# 		Splitting on page-break at id=sigil_toc_id_78
# 		Splitting on page-break at id=sigil_toc_id_79
# 		Splitting on page-break at id=sigil_toc_id_80
# 		Splitting on page-break at id=sigil_toc_id_81
# 		Splitting on page-break at id=sigil_toc_id_82
# 		Splitting on page-break at id=sigil_toc_id_83
# 		Splitting on page-break at id=sigil_toc_id_84
# 		Splitting on page-break at id=sigil_toc_id_85
# 		Splitting on page-break at id=sigil_toc_id_86
# 		Splitting on page-break at id=sigil_toc_id_87
# 		Splitting on page-break at id=sigil_toc_id_88
# 		Splitting on page-break at id=sigil_toc_id_89
# 		Splitting on page-break at id=sigil_toc_id_90
# 		Splitting on page-break at id=sigil_toc_id_91
# 		Splitting on page-break at id=sigil_toc_id_92
# 		Splitting on page-break at id=sigil_toc_id_93
# 		Splitting on page-break at id=sigil_toc_id_94
# 		Splitting on page-break at id=sigil_toc_id_95
# 		Splitting on page-break at id=calibre_pb_73
# 		Splitting on page-break at id=sigil_toc_id_96
# 		Splitting on page-break at id=sigil_toc_id_97
# 		Splitting on page-break at id=sigil_toc_id_98
# 		Splitting on page-break at id=calibre_pb_77
# 		Splitting on page-break at id=calibre_pb_78
# 		Splitting on page-break at id=calibre_pb_79
# 		Splitting on page-break at id=calibre_pb_80
# 		Splitting on page-break at id=calibre_pb_81
# 		Splitting on page-break at id=calibre_pb_82
# 		Splitting on page-break at id=calibre_pb_83
# 		Splitting on page-break at id=calibre_pb_84
# 		Splitting on page-break at id=calibre_pb_85
# 		Splitting on page-break at id=calibre_pb_86
# 		Splitting on page-break at id=calibre_pb_87
# 		Splitting on page-break at id=calibre_pb_88
# 		Splitting on page-break at id=calibre_pb_89
# 		Splitting on page-break at id=calibre_pb_90
# 		Splitting on page-break at id=sigil_toc_id_99
# 	Split into 84 parts
# 		Splitting on page-break at id=calibre_pb_0
# 		Splitting on page-break at id=calibre_pb_1
# 	Split into 2 parts
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_001.html#sigil_toc_id_24
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_002.html#sigil_toc_id_25
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_003.html#sigil_toc_id_26
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_004.html#sigil_toc_id_27
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_005.html#sigil_toc_id_28
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_006.html#sigil_toc_id_29
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_007.html#sigil_toc_id_30
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_008.html#sigil_toc_id_31
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_009.html#sigil_toc_id_32
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_010.html#sigil_toc_id_33
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_011.html#sigil_toc_id_34
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_012.html#sigil_toc_id_35
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_013.html#sigil_toc_id_36
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_014.html#sigil_toc_id_37
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_015.html#sigil_toc_id_38
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_016.html#sigil_toc_id_39
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_017.html#sigil_toc_id_40
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_018.html#sigil_toc_id_41
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_019.html#sigil_toc_id_42
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_020.html#sigil_toc_id_43
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_021.html#sigil_toc_id_44
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_022.html#sigil_toc_id_45
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_023.html#sigil_toc_id_46
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_024.html#sigil_toc_id_47
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_025.html#sigil_toc_id_48
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_026.html#sigil_toc_id_49
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_027.html#sigil_toc_id_50
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_028.html#sigil_toc_id_51
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_029.html#sigil_toc_id_52
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_030.html#sigil_toc_id_53
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_031.html#sigil_toc_id_54
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_032.html#sigil_toc_id_55
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_033.html#sigil_toc_id_56
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_034.html#sigil_toc_id_57
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_035.html#sigil_toc_id_58
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_036.html#sigil_toc_id_59
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_037.html#sigil_toc_id_60
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_038.html#sigil_toc_id_61
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_039.html#sigil_toc_id_62
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_040.html#sigil_toc_id_63
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_041.html#sigil_toc_id_64
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_042.html#sigil_toc_id_65
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_043.html#sigil_toc_id_66
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_044.html#sigil_toc_id_67
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_045.html#sigil_toc_id_68
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_046.html#sigil_toc_id_69
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_047.html#sigil_toc_id_70
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_048.html#sigil_toc_id_71
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_049.html#sigil_toc_id_72
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_050.html#sigil_toc_id_73
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_051.html#sigil_toc_id_74
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_052.html#sigil_toc_id_75
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_053.html#sigil_toc_id_76
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_054.html#sigil_toc_id_77
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_055.html#sigil_toc_id_78
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_056.html#sigil_toc_id_79
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_057.html#sigil_toc_id_80
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_058.html#sigil_toc_id_81
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_059.html#sigil_toc_id_82
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_060.html#sigil_toc_id_83
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_061.html#sigil_toc_id_84
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_062.html#sigil_toc_id_85
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_063.html#sigil_toc_id_86
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_064.html#sigil_toc_id_87
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_065.html#sigil_toc_id_88
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_066.html#sigil_toc_id_89
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_067.html#sigil_toc_id_90
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_068.html#sigil_toc_id_91
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_069.html#sigil_toc_id_92
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_070.html#sigil_toc_id_93
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_071.html#sigil_toc_id_94
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_072.html#sigil_toc_id_95
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_073.html#sigil_toc_id_96
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_074.html#sigil_toc_id_97
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_075.html#sigil_toc_id_98
# Removing anchor from TOC href: OEBPS/Text/mmt-manuscript_split_083.html#sigil_toc_id_99
# The cover image has an id != "cover". Renaming to work around bug in Nook Color
# Upgrading to EPUB 3...
# EPUB output written to /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/__Mind Management, Not Time Management.epub
# Output saved to   /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/__Mind Management, Not Time Management.epub
#
#
# *******************************************************************************
# NOTE:
# The warning "Character xx not found in the vocabulary."
# MEANS THE MODEL CANNOT INTERPRET THE CHARACTER AND WILL MAYBE GENERATE
# (AS WELL AS WRONG PUNCTUATION POSITION) AN HALLUCINATION TO IMPROVE THIS MODEL,
# IT NEEDS TO ADD THIS CHARACTER INTO A NEW TRAINING MODEL.
# YOU CAN IMPROVE IT OR ASK TO A TRAINING MODEL EXPERT.
# *******************************************************************************
#
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.1.0.json: 122kB [00:00, 143MB/s]
# 2025-09-07 14:37:58 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.1.0/en/default.zip: 100% 428M/428M [01:17<00:00, 5.50MB/s]
# 2025-09-07 14:39:21 INFO: Finished downloading models and saved to /content/ebook2audiobook/models/stanza.
# 2025-09-07 14:39:21 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | ner       | ontonotes |
# =========================
#
# 2025-09-07 14:39:21 INFO: Use device: gpu
# 2025-09-07 14:39:21 INFO: Loading: tokenize
# /usr/local/lib/python3.12/dist-packages/stanza/models/tokenize/trainer.py:85: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2025-09-07 14:39:22 INFO: Loading: ner
# /usr/local/lib/python3.12/dist-packages/stanza/models/ner/trainer.py:116: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# /usr/local/lib/python3.12/dist-packages/stanza/models/common/char_model.py:130: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   state = torch.load(filename, lambda storage, loc: storage)
# 2025-09-07 14:39:22 INFO: Done loading processors!
# Analyzing numbers, maths signs, dates and time to convert in words...
# speakers_xtts.pth: 100% 7.75M/7.75M [00:00<00:00, 14.4MB/s]
# /content/ebook2audiobook/lib/classes/tts_engines/coqui.py:51: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   xtts_builtin_speakers_list = torch.load(self.speakers_path)
# Loading TTS xtts model, it takes a while, please be patient...
# config.json: 4.37kB [00:00, 15.0MB/s]
# model.pth: 100% 1.87G/1.87G [00:27<00:00, 68.0MB/s]
# vocab.json: 361kB [00:00, 22.6MB/s]
# 2025-09-07 14:40:15.797945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757256016.056221    5958 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757256016.125319    5958 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757256016.642362    5958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757256016.642396    5958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757256016.642401    5958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757256016.642410    5958 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-07 14:40:16.690717: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# xtts Loaded!
# --------------------------------------------------
# A total of 87 blocks and 2366 sentences.
# --------------------------------------------------
# 0.00%:   0% 0/3410 [00:00<?, ?step/s]Block 1 containing 1 sentences...
# Computing speaker latents...
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.03%:   0% 0/3410 [00:08<?, ?step/s] | Also by David Kadavy The Heart to Start: Stop Procrastinating and Start Creating Design for Hackers: Reverse-Engineering Beauty Short Read How to Write a Book
# 0.03%:   0% 1/3410 [00:08<7:35:50,  8.02s/step]End of Block 1
# Input #0, concat, from '/tmp/tmpyeryee14/chunk_0000.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16
# Stream mapping:
#   Stream #0:0 -> #0:0 (flac (native) -> flac (native))
# Press [q] to stop, [?] for help
# Output #0, flac, to '/tmp/tmpyeryee14/chunk_0000.flac':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 flac
# size=     325kB time=00:00:12.39 bitrate= 215.1kbits/s speed= 264x
# video:0kB audio:317kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.550727%
# Input #0, concat, from '/tmp/tmpyeryee14/sentences_final.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16
# Stream mapping:
#   Stream #0:0 -> #0:0 (flac (native) -> flac (native))
# Press [q] to stop, [?] for help
# Output #0, flac, to '/content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/chapters/chapter_1.flac':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 flac
# size=     325kB time=00:00:12.39 bitrate= 215.1kbits/s speed= 249x
# video:0kB audio:317kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.550727%
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/chapters/chapter_1.flac
# Combining block 1 to audio, sentence 0 to 1
# Block 2 containing 5 sentences...
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.06%:   0% 1/3410 [00:11<7:35:50,  8.02s/step] | two thousand and twenty David Kadavy. All rights reserved.
# 0.09%:   0% 2/3410 [00:11<5:13:38,  5.52s/step] | ‡break‡
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.12%:   0% 3/3410 [00:19<5:13:32,  5.52s/step] | Cover design by David Kadavy Illustrations by David Kadavy ebook designed and coded by David Kadavy Thank you for for complying with copyright laws by getting this book through legal means, and by not reproducing, scanning,
# 0.15%:   0% 4/3410 [00:25<4:14:18,  4.48s/step] | or distributing any part of this book, aside from brief quotations. Kadavy, Inc. is an independent content producer and depends upon your support to produce books like this.
# 0.18%:   0% 5/3410 [00:25<4:34:00,  4.83s/step] | ‡break‡
# 0.21%:   0% 6/3410 [00:31<4:33:55,  4.83s/step] | Any Internet addresses, phone numbers, or company or product information printed in this book are offered as a resource and are not intended in any way to be or to imply an endorsement by Kadavy, Inc., nor does Kadavy,
# 0.21%:   0% 7/3410 [00:31<3:48:09,  4.02s/step]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.23%:   0% 7/3410 [00:36<3:48:09,  4.02s/step] | Inc. vouch for the existence, content, or services of these sites, phone numbers, companies, or products beyond the life of this book.
# 0.26%:   0% 8/3410 [00:36<4:02:51,  4.28s/step] | ‡break‡
# End of Block 2
# Input #0, concat, from '/tmp/tmpb9d4_jsw/chunk_0000.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16
# Stream mapping:
#   Stream #0:0 -> #0:0 (flac (native) -> flac (native))
# Press [q] to stop, [?] for help
# Output #0, flac, to '/tmp/tmpb9d4_jsw/chunk_0000.flac':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 flac
# size=    1502kB time=00:01:00.58 bitrate= 203.0kbits/s speed= 521x
# video:0kB audio:1494kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.541881%
# Input #0, concat, from '/tmp/tmpb9d4_jsw/sentences_final.txt':
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16
# Stream mapping:
#   Stream #0:0 -> #0:0 (flac (native) -> flac (native))
# Press [q] to stop, [?] for help
# Output #0, flac, to '/content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/chapters/chapter_2.flac':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Audio: flac, 24000 Hz, mono, s16, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 flac
# size=    1502kB time=00:01:00.58 bitrate= 203.0kbits/s speed= 526x
# video:0kB audio:1494kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.541881%
# ********* Combined block audio file saved in /content/ebook2audiobook/tmp/proc-cab80e5f-04d1-4884-833a-35e08924f454/b6f8bed63ad949895e946a0f6cdbd0cd/chapters/chapter_2.flac
# Combining block 2 to audio, sentence 1 to 5
# Block 3 containing 72 sentences...
# 0.29%:   0% 9/3410 [00:37<4:02:47,  4.28s/step] | Table of Contents
# 0.32%:   0% 10/3410 [00:37<2:39:37,  2.82s/step] | ‡pause‡
# 0.35%:   0% 11/3410 [00:38<2:39:34,  2.82s/step] | Also by David Kadavy
# 0.38%:   0% 12/3410 [00:38<1:48:51,  1.92s/step] | ‡pause‡
# 0.41%:   0% 13/3410 [00:39<1:48:49,  1.92s/step] | Bonus Material
# 0.44%:   0% 14/3410 [00:39<1:16:22,  1.35s/step] | ‡pause‡
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.47%:   0% 15/3410 [00:41<1:16:21,  1.35s/step] | Chapter one: Mind Management, Not Time Management Welcome to the Creative Age
# 0.50%:   0% 16/3410 [00:41<1:13:25,  1.30s/step] | ‡pause‡
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.53%:   0% 17/3410 [00:42<1:13:24,  1.30s/step] | The End of Time Management
# 0.56%:   1% 18/3410 [00:42<58:23,  1.03s/step] | ‡pause‡
# 0.59%:   1% 19/3410 [00:43<58:22,  1.03s/step] | Time Worship
# 0.62%:   1% 20/3410 [00:43<45:13,  1.25step/s] | ‡pause‡
# 0.65%:   1% 21/3410 [00:44<45:12,  1.25step/s] | When You Save Time, Keep it
# 0.67%:   1% 22/3410 [00:44<40:08,  1.41step/s] | ‡pause‡
# 0.70%:   1% 23/3410 [00:46<40:07,  1.41step/s] | The Two False Assumptions of Time Management
# 0.73%:   1% 24/3410 [00:46<46:19,  1.22step/s] | ‡pause‡
# 0.76%:   1% 25/3410 [00:47<46:18,  1.22step/s] | Beyond Time Management
# 0.79%:   1% 26/3410 [00:47<39:06,  1.44step/s] | ‡pause‡
# 0.82%:   1% 27/3410 [00:48<39:05,  1.44step/s] | Why I Moved to Another Continent
# 0.85%:   1% 28/3410 [00:48<35:13,  1.60step/s] | ‡pause‡
# 0.88%:   1% 29/3410 [00:49<35:12,  1.60step/s] | From a Time Management World to a Mind Management World
# 0.91%:   1% 30/3410 [00:49<37:11,  1.51step/s] | ‡pause‡
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# 0.94%:   1% 31/3410 [00:51<37:11,  1.51step/s] | Chapter two: Creative Sweet Spot Divergent/Convergent
# 0.97%:   1% 32/3410 [00:51<41:44,  1.35step/s] | ‡pause‡
# 1.00%:   1% 33/3410 [00:52<41:43,  1.35step/s] | A Microcosm of Creativity
# 1.03%:   1% 34/3410 [00:52<39:26,  1.43step/s] | ‡pause‡
# 1.06%:   1% 35/3410 [00:53<39:25,  1.43step/s] | The Sudden Nature of Insight
# 1.09%:   1% 36/3410 [00:53<35:21,  1.59step/s] | ‡pause‡
# 1.11%:   1% 37/3410 [00:54<35:21,  1.59step/s] | Illuminating the Not-So-Obvious
# 1.14%:   1% 38/3410 [00:54<33:31,  1.68step/s] | ‡pause‡
# 1.17%:   1% 39/3410 [00:55<33:30,  1.68step/s] | Not All Hours Are Equal
# 1.20%:   1% 40/3410 [00:55<30:38,  1.83step/s] | ‡pause‡
# 1.23%:   1% 41/3410 [00:56<30:37,  1.83step/s] | Fire the CEO "of Your Brain"
# 1.26%:   1% 42/3410 [00:56<32:56,  1.70step/s] | ‡pause‡
# 1.29%:   1% 43/3410 [00:58<32:56,  1.70step/s] | Create the Conditions for Collision
# 1.32%:   1% 44/3410 [00:58<33:58,  1.65step/s] | ‡pause‡
# 1.35%:   1% 45/3410 [00:58<33:57,  1.65step/s] | The First-Hour Rule
# 1.38%:   1% 46/3410 [00:58<29:17,  1.91step/s] | ‡pause‡
# 1.41%:   1% 47/3410 [00:59<29:17,  1.91step/s] | The Gift of Groggy
# 1.44%:   1% 48/3410 [00:59<25:43,  2.18step/s] | ‡pause‡
# 1.47%:   1% 49/3410 [01:00<25:43,  2.18step/s] | Flipping the Temporal Switch
# 1.50%:   1% 50/3410 [01:00<24:54,  2.25step/s] | ‡pause‡
# 1.52%:   1% 51/3410 [01:01<24:54,  2.25step/s] | Why Are There Eight Days in a Week?
# 1.55%:   2% 52/3410 [01:01<29:30,  1.90step/s] | ‡pause‡
# 1.58%:   2% 53/3410 [01:03<29:30,  1.90step/s] | Creativity is a Maze, Not a Jogging Path
# 1.61%:   2% 54/3410 [01:03<36:47,  1.52step/s] | ‡pause‡
# 1.64%:   2% 55/3410 [01:04<36:46,  1.52step/s] | The High Interest Rate of Borrowed Time
# 1.67%:   2% 56/3410 [01:04<33:56,  1.65step/s] | ‡pause‡
# 1.70%:   2% 57/3410 [01:05<33:55,  1.65step/s] | Making Up Time
# 1.73%:   2% 58/3410 [01:05<29:20,  1.90step/s] | ‡pause‡
